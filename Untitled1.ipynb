# %% [markdown]
# <a href="https://colab.research.google.com/github/terryga8n/licence-detection-system/blob/main/Untitled1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# run and install ultralyics and open cv

# %%
# !pip install torch torchvision torchaudio
# !pip install opencv-python
# !pip install ultralytics
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 363.4/363.4 MB 4.2 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.8/13.8 MB 57.1 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 24.6/24.6 MB 51.4 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 883.7/883.7 kB 42.7 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 664.8/664.8 MB 2.6 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 211.5/211.5 MB 5.9 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.3/56.3 MB 12.7 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 127.9/127.9 MB 7.3 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 207.5/207.5 MB 4.1 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 21.1/21.1 MB 58.4 MB/s eta 0:00:00
# ...
#   Attempting uninstall: nvidia-nvjitlink-cu12
#     Found existing installation: nvidia-nvjitlink-cu12 12.5.82
#     Uninstalling nvidia-nvjitlink-cu12-12.5.82:
# ...

# %% [markdown]
# import yolov11 from ultralytics

# %%
# prompt: install yolov11

from ultralytics import YOLO
# Out:
# Creating new Ultralytics Settings v0.0.6 file ✅
# View Ultralytics Settings with 'yolo settings' or at '/root/.config/Ultralytics/settings.json'
# Update Settings with 'yolo settings key=value', i.e. 'yolo settings runs_dir=path/to/dir'. For help see https://docs.ultralytics.com/quickstart/#ultralytics-settings.

# %% [markdown]
# insert annotated data from roboflow

# %%
# !pip install roboflow

from roboflow import Roboflow
rf = Roboflow(api_key="A4ZB691N7VcVOtHn48kg")
project = rf.workspace("ta-jfzoz").project("licence-detection-fy0ma")
version = project.version(2)
dataset = version.download("yolov11")
# Out:
# ...
# loading Roboflow workspace...
# loading Roboflow project...

# %% [markdown]
# navigate to folder
#
# ```
# # This is formatted as code
# ```

# %%
dataset.location
# Out:
# '/content/licence-detection-2'

# %% [markdown]
# import packages

# %%
import os
os.environ['PATH'] += ":/usr/local/lib/python3.10/dist-packages/ultralytics"

# %% [markdown]
# train model on the data

# %%
# !yolo task=detect mode=train data={dataset.location}/data.yaml model="yolo11n.pt"  epochs=100 imgsz=640
# Out:
# ...
# 100% 5.35M/5.35M [00:00<00:00, 99.8MB/s]
# Ultralytics 8.3.94 🚀 Python-3.11.11 torch-2.6.0+cu124 CUDA:0 (Tesla T4, 15095MiB)
# ...

# %% [markdown]
# results

# %%
from IPython.display import Image
Image("/content/runs/detect/train/results.png", width=640)

# %% [markdown]
# confusion matrix

# %%
from IPython.display import Image
Image("/content/runs/detect/train/confusion_matrix.png", width=600)

# %%
Image("/content/runs/detect/train/labels.jpg", width=600)

# %%
Image()

# %%
Image("/content/runs/detect/train/train_batch0.jpg", width=600)

# %%
Image("/content/runs/detect/train/train_batch2.jpg", width=600)

# %% [markdown]
# transfer to using our model, best.pt

# %%
# !yolo task=detect mode=val  model="/content/runs/detect/train/weights/best.pt" data={dataset.location}/data.yaml
# Out:
# Ultralytics 8.3.94 🚀 Python-3.11.11 torch-2.6.0+cu124 CUDA:0 (Tesla T4, 15095MiB)
# YOLO11n summary (fused): 100 layers, 2,582,347 parameters, 0 gradients, 6.3 GFLOPs
# val: Scanning /content/licence-detection-2/valid/labels.cache... 26 images, 0 backgrounds, 0 corrupt: 100% 26/26 [00:00<?, ?it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 2/2 [00:01<00:00,  1.90it/s]
#                    all         26         26      0.953          1      0.989      0.715
# Speed: 0.3ms preprocess, 14.7ms inference, 0.0ms loss, 8.3ms postprocess per image
# Results saved to runs/detect/val
# 💡 Learn more at https://docs.ultralytics.com/modes/val

# %% [markdown]
# run prediction using our model on the test images

# %%
# !yolo task=detect mode=predict  model="/content/runs/detect/train/weights/best.pt"  conf=0.25 source={dataset.location}/test/images save=True
# Out:
# Ultralytics 8.3.94 🚀 Python-3.11.11 torch-2.6.0+cu124 CUDA:0 (Tesla T4, 15095MiB)
# YOLO11n summary (fused): 100 layers, 2,582,347 parameters, 0 gradients, 6.3 GFLOPs
#
# image 1/13 /content/licence-detection-2/test/images/back_side_add7733_JPG.rf.67bb864c03008d3397e9b3daa985e8fe.jpg: 640x640 1 zimbabwe-license-plates, 11.2ms
# image 2/13 /content/licence-detection-2/test/images/back_side_aeo2124_JPG.rf.729435d1ca68f0f665cb151891a60f98.jpg: 640x640 1 zimbabwe-license-plates, 9.2ms
# image 3/13 /content/licence-detection-2/test/images/back_side_aeq1594_JPG.rf.cf721325444d1ab9cfea9d7bfb8d010a.jpg: 640x640 1 zimbabwe-license-plates, 8.3ms
# image 4/13 /content/licence-detection-2/test/images/back_side_agd5443_JPG.rf.9b47cbf31c2241c24a932580c60dafc1.jpg: 640x640 1 zimbabwe-license-plates, 8.1ms
# image 5/13 /content/licence-detection-2/test/images/front_side_abo3920_JPG.rf.d092d4dcd0ec7dee769ba8ec1fb3cec9.jpg: 640x640 1 zimbabwe-license-plates, 8.5ms
# ...

# %% [markdown]
# test results

# %%
Image("/content/runs/detect/predict/processed-hsn867b2s_jpg.rf.27a63641c04e8b6072802467a6a264fc.jpg", width=640)

# %% [markdown]
# crop window of context required

# %%
result = ('/content/runs/detect/predict/processed-hsn867b2s_jpg.rf.27a63641c04e8b6072802467a6a264fc.jpg'),
xyxy = results[0].boxes.xyxy.cpu().numpy ()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-19-b07fbb5fc454> in <cell line: 0>()
#       1 result=('/content/runs/detect/predict/processed-hsn867b2s_jpg.rf.27a63641c04e8b6072802467a6a264fc.jpg'),
# ----> 2 xyxy =results[0].boxes.xyxy.cpu().numpy ()
#
# NameError: name 'results' is not defined
